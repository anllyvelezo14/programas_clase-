# %% [markdown]
# # Cancelación sustractiva

# %%
a=1.0
b=1.0
x_list =[]
y_list =[]

for i in range (1,10):
    c=10**(-i)
    x_1= (-b+(b**2-4*a*c)**0.5)/(2*a)       
    x_1_p = 2*c/(-b-(b**2-4*a*c)**0.5)
    error = abs(x_1_p - x_1)/ abs(x_1_p)*100.
    
    x_list.append(c)
    y_list.append(error)
    print("c=%.5e x_1=%.16e x_1_p=%.16e error=%.16ef"%(c,x_1,x_1_p,error))
# Out:
# c=1.00000e-01 x_1=-1.1270166537925830e-01 x_1_p=-1.1270166537925831e-01 error=1.2313738010093799e-14f
# c=1.00000e-02 x_1=-1.0102051443364402e-02 x_1_p=-1.0102051443364381e-02 error=2.0606390522189731e-13f
# c=1.00000e-03 x_1=-1.0010020050140178e-03 x_1_p=-1.0010020050140421e-03 error=2.4261818200188931e-12f
# c=1.00000e-04 x_1=-1.0001000200049459e-04 x_1_p=-1.0001000200050015e-04 error=5.5559804247983337e-12f
# c=1.00000e-05 x_1=-1.0000100002016676e-05 x_1_p=-1.0000100002000051e-05 error=1.6625396431417928e-10f
# c=1.00000e-06 x_1=-1.0000010000066339e-06 x_1_p=-1.0000010000020000e-06 error=4.6339008622813331e-10f
# c=1.00000e-07 x_1=-1.0000000999488279e-07 x_1_p=-1.0000001000000200e-07 error=5.1192151583771568e-09f
# c=1.00000e-08 x_1=-1.0000000105758744e-08 x_1_p=-1.0000000100000004e-08 error=5.7587403771393922e-08f
# c=1.00000e-09 x_1=-1.0000000272292198e-09 x_1_p=-1.0000000010000002e-09 error=2.6229219530110447e-06f

# %%
##grafica del error 

import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
## corrige la grafica (sale solo una)

fig=plt.figure(figsize=(10,10))
ax=plt.axes()
ax.grid()
ax.plot(x_list,y_list,'.')
ax.set_yscale('log') ##modificando a escala logaritmica
ax.set_xscale('log')
ax.set_xlabel("c")
ax.set_ylabel("error")
plt.show()
